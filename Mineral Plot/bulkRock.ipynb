# %%
import matplotlib.pyplot as mlib
import mpltern as mpl
import numpy as np
import pandas as pd
import os

from loadEPMA import excelLoad

to=excelLoad(1)

# %%
## K2O/SiO2 Diagram Skeleton

fig, ax=mlib.subplots()
KSi1=np.arange(43,81)
KSi2=np.arange(43,57)
KSi3=np.arange(56,71)
KSi4=np.arange(52,71)
KSi5=np.arange(70,81)

KSi1_1=(2/45)*KSi1-(163/90)
KSi2_1=(17/180)*KSi4-(65/18)
KSi3_1=0.2*KSi2-8
KSi4_1=(4/35)*KSi3-(16/5)
KSi5_1=(1/100)*KSi5+(41/10)

ax.plot(KSi1,KSi1_1)
ax.plot(KSi4,KSi2_1)
ax.plot(KSi2,KSi3_1)
ax.plot(KSi3,KSi4_1)
ax.plot(KSi5,KSi5_1)

ax.set(xlim=(46,80),ylim=(0,6))

ax.vlines(x=52,ymin=0,ymax=4)
ax.vlines(x=56,ymin=0,ymax=4.5)
ax.vlines(x=63,ymin=0,ymax=5)
ax.vlines(x=70,ymin=0,ymax=5.5)
