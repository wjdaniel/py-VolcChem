# %%
import matplotlib.pyplot as mlib
import mpltern as mpl
import numpy as np
import pandas as pd
import os

from loadEPMA import excelLoad
from wrFunction import wrKClass
excelLoad(1)

wrKClass()

# %%
# Out:
# Text(0.5, 0, 'wt.% SiO$_{2}$')
