# %%
import matplotlib.pyplot as mlib
import mpltern as mpl
import numpy as np
import pandas as pd
import os

from loadEPMA import excelLoad
from wrFunction import *
wrVariables=excelLoad(1)
fig1=wrKClass()
fig1.plot(wrVariables[['SiO2']],wrVariables[['K2O']],'x')

# %%
wrANK()
# Out:
# <AxesSubplot: xlabel='Al$_{2}$O$_{3}$/[CaO+Na$_{2}$O+K$_{2}$O]', ylabel='Al$_{2}$O$_{3}$/[Na$_{2}$O+K$_{2}$O]'>

# %%
wrTAS()
# Out:
# <AxesSubplot: xlabel='SiO$_{2}$', ylabel='Na$_{2}$O+K$_{2}$O'>

# %%
a=np.asarray([45, 52.5])
Sis=np.linspace(0,16,100)
